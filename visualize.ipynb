# %%
f = open("pos_ls_x.txt")
lines = f.readlines()
x_pos_ls=[]
for line in lines: 
    line=line.rstrip().split(",")
    line=[float(x) for x in line]
    x_pos_ls.append(line)

# %%
f = open("pos_ls_y.txt")
lines = f.readlines()
y_pos_ls=[]
for line in lines: 
    line=line.rstrip().split(",")
    line=[float(x) for x in line]
    y_pos_ls.append(line)

# %%
f = open("pos_ls_x_b.txt")
lines = f.readlines()
x_pos_ls_b=[]
for line in lines: 
    line=line.rstrip().split(",")
    line=[float(x) for x in line]
    x_pos_ls_b.append(line)

# %%
f = open("pos_ls_y_b.txt")
lines = f.readlines()
y_pos_ls_b=[]
for line in lines: 
    line=line.rstrip().split(",")
    line=[float(x) for x in line]
    y_pos_ls_b.append(line)

# %%
nx=500
dt=0.001
import matplotlib.pyplot as plt 
figure=plt.figure(figsize=(10,10))
ax = plt.subplot(1,2,1)
ax.scatter(0,-1,marker="x",s=200)
ax.scatter(0,1,marker="o",s=200)

for idx in range(len(y_pos_ls_b)):
    ax.plot(x_pos_ls_b[idx], y_pos_ls_b[idx],color="blue")
for idx in range(len(y_pos_ls)):
    ax.plot(x_pos_ls[idx], y_pos_ls[idx],color="orange")
plt.legend()
plt.xlim([-3,1])
# Out:
# No handles with labels found to put in legend.
# (-3.0, 1.0)

# %%
for x in x_pos_ls_b:
    print(len(x))
# Out:
# 17692
# 17649
# 17962
# 18050
# 18050
